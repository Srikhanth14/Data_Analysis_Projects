# %% [markdown]
# <a href="https://colab.research.google.com/github/Srikhanth14/Data_Analysis_Projects/blob/main/HealthCare_Resource_Optimization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Import the Necessary Libraries**

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # **Data Collection and Processing**

# %%
#Loading the Datasets
data = pd.read_csv("modified_healthcare_dataset.csv")

# %%
# Display first three rows of the dataset
data.head(3)
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby Jackson   19  Female        AB+        Infections        2024-01-31
# 1   Leslie Terry   15  Female         B-               Flu        2019-08-20
# 2    Danny Smith   50  Female         A+            Cancer        2022-09-22
#
#              Doctor                                     Hospital  \
# 0     Matthew Smith               Northwestern Memorial Hospital
# 1   Samantha Davies  UI Health (University of Illinois Hospital)
# 2  Tiffany Mitchell  UI Health (University of Illinois Hospital)
#
#   Insurance Provider  Billing Amount  Room Number Admission Type  \
# 0         Blue Cross     2212.272701          328      Emergency
# 1   UnitedHealthcare     3185.161388          265      Emergency
# 2         Blue Cross    72055.214065          205       Elective
#
#   Discharge Date    Medication  Test Results  Length of Stay
# 0     2024-02-07  Azithromycin        Normal               7
# 1     2019-08-22       Tamiflu      Abnormal               2
# 2     2022-10-30     Cisplatin  Inconclusive              38

# %%
# Display last four rows of the dataset
data.tail(4)
# Out:
#                  Name  Age  Gender Blood Type Medical Condition  \
# 55496      Kyle Perez   63    Male         A+     Heart Disease
# 55497    Heather Wang   28  Female         O+            Asthma
# 55498  Jennifer Jones   75    Male         O+            Cancer
# 55499    James Garcia   53  Female         O+          Diabetes
#
#       Date of Admission           Doctor  \
# 55496        2020-01-23  Taylor Sullivan
# 55497        2020-07-13   Joe Jacobs DVM
# 55498        2019-05-25   Kimberly Curry
# 55499        2024-04-02    Dennis Warren
#
#                                           Hospital Insurance Provider  \
# 55496  UI Health (University of Illinois Hospital)           Medicare
# 55497               Northwestern Memorial Hospital              Cigna
# 55498                            UChicago Medicine              Aetna
# 55499             Loyola University Medical Center              Cigna
#
#        Billing Amount  Room Number Admission Type Discharge Date  \
# 55496    26828.223456          316      Emergency     2020-03-07
# 55497     6041.030866          347       Elective     2020-07-16
# 55498    44495.656362          321      Emergency     2019-07-11
# 55499    15953.455966          448      Emergency     2024-04-12
#
#          Medication Test Results  Length of Stay
# 55496       Statins     Abnormal              44
# 55497   Montelukast       Normal               3
# 55498  Methotrexate     Abnormal              47
# 55499       Insulin     Abnormal              10

# %%
#Display the Sample of any 2 rows from the dataset
data.sample(2)
# Out:
#                    Name  Age Gender Blood Type Medical Condition  \
# 13857      Erica Cooley   73   Male        AB+     Heart Disease
# 43012  Christina Nguyen   61   Male         O+     Heart Disease
#
#       Date of Admission             Doctor  \
# 13857        2023-01-06  Mrs. Ashley James
# 43012        2020-06-23         Tanya West
#
#                                           Hospital Insurance Provider  \
# 13857                            UChicago Medicine              Cigna
# 43012  UI Health (University of Illinois Hospital)           Medicare
#
#        Billing Amount  Room Number Admission Type Discharge Date Medication  \
# 13857    30906.563041          468      Emergency     2023-01-18    Statins
# 43012    68121.103506          317      Emergency     2020-07-05    Statins
#
#        Test Results  Length of Stay
# 13857      Abnormal              12
# 43012  Inconclusive              12

# %%
#Print the Dimensions of the dataset
print("Number of Rows: ", data.shape[0])
print("Number of Columns: ", data.shape[1])
# Out:
# Number of Rows:  55500
# Number of Columns:  16

# %%
#Displaying all column names in the Dataset
for col in data.columns:
  print(col)
# Out:
# Name
# Age
# Gender
# Blood Type
# Medical Condition
# Date of Admission
# Doctor
# Hospital
# Insurance Provider
# Billing Amount
# Room Number
# Admission Type
# Discharge Date
# Medication
# Test Results
# Length of Stay

# %%
#Checking the Data type of Columns in the Dataset
data.dtypes.to_frame(name="Data_Type")
# Out:
#                    Data_Type
# Name                  object
# Age                    int64
# Gender                object
# Blood Type            object
# Medical Condition     object
# Date of Admission     object
# Doctor                object
# Hospital              object
# Insurance Provider    object
# Billing Amount       float64
# Room Number            int64
# Admission Type        object
# Discharge Date        object
# Medication            object
# Test Results          object
# Length of Stay         int64

# %%
# Checking any null values present in the each column
if data.isnull().sum().sum() == 0:
  print("No null values present in the dataset")
else:
  print("Null values present in the dataset")
# Out:
# No null values present in the dataset

# %%
print(data.isnull().sum())
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# Length of Stay        0
# dtype: int64

# %%
#Checking any duplicate values present in the Dataset
if data.duplicated().sum() == 0:
  print("Duplicate values doesn't exist in the dataset")
else:
  print("Duplicate values exist in the dataset")
# Out:
# Duplicate values doesn't exist in the dataset

# %%
#Statistical Summary of the Dataset
data.describe()
# Out:
#                 Age  Billing Amount   Room Number  Length of Stay
# count  55500.000000    55500.000000  55500.000000    55500.000000
# mean      48.001622    21835.044635    301.134829       17.841009
# std       21.105827    23574.413594    115.243069       20.272294
# min        5.000000      500.220989    101.000000        1.000000
# 25%       32.000000     4195.525741    202.000000        4.000000
# 50%       50.000000    11089.537763    302.000000        8.000000
# 75%       65.000000    35887.703406    401.000000       28.000000
# max       90.000000    99997.797977    500.000000       89.000000

# %%
#Overview of the Dataset
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 55500 entries, 0 to 55499
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                55500 non-null  object
#  1   Age                 55500 non-null  int64
#  2   Gender              55500 non-null  object
#  3   Blood Type          55500 non-null  object
#  4   Medical Condition   55500 non-null  object
#  5   Date of Admission   55500 non-null  object
#  6   Doctor              55500 non-null  object
#  7   Hospital            55500 non-null  object
#  8   Insurance Provider  55500 non-null  object
#  9   Billing Amount      55500 non-null  float64
#  10  Room Number         55500 non-null  int64
#  11  Admission Type      55500 non-null  object
#  12  Discharge Date      55500 non-null  object
#  13  Medication          55500 non-null  object
#  14  Test Results        55500 non-null  object
#  15  Length of Stay      55500 non-null  int64
# dtypes: float64(1), int64(3), object(12)
# memory usage: 6.8+ MB

# %%
#Identifying the Total unique values in Each Column
data.nunique()
# Out:
# Name                  40235
# Age                      86
# Gender                    2
# Blood Type                8
# Medical Condition         8
# Date of Admission      1827
# Doctor                40341
# Hospital                  4
# Insurance Provider        5
# Billing Amount        55500
# Room Number             400
# Admission Type            4
# Discharge Date         1901
# Medication               23
# Test Results              3
# Length of Stay           89
# dtype: int64

# %%
Categorical_Target_Columns = ["Gender","Blood Type", "Medical Condition", "Doctor", "Hospital", "Insurance Provider", "Admission Type", "Medication", "Test Results"]

for categorical_columns in Categorical_Target_Columns:
    print(data[categorical_columns].value_counts())
    print("-"*50)
# Out:
# Gender
# Female    27955
# Male      27545
# Name: count, dtype: int64
# --------------------------------------------------
# Blood Type
# O+     15696
# A+     15573
# B+      5457
# AB-     4485
# B-      4408
# O-      3341
# A-      3301
# AB+     3239
# Name: count, dtype: int64
# --------------------------------------------------
# Medical Condition
# Flu              7046
# Diabetes         7005
# Obesity          6994
# Cancer           6940
# Asthma           6908
# Heart Disease    6900
# Alzheimer’s      6861
# Infections       6846
# Name: count, dtype: int64
# --------------------------------------------------
# Doctor
# Michael Smith      27
# John Smith         22
# Robert Smith       22
# Michael Johnson    20
# James Smith        20
#                    ..
# Keith Ortiz         1
# Timothy Chapman     1
# Terri Collins       1
# Jill Jacobson       1
# Scott Coleman       1
# Name: count, Length: 40341, dtype: int64
# --------------------------------------------------
# Hospital
# Northwestern Memorial Hospital                 14070
# UI Health (University of Illinois Hospital)    13950
# UChicago Medicine                              13870
# Loyola University Medical Center               13610
# Name: count, dtype: int64
# --------------------------------------------------
# Insurance Provider
# Cigna               11183
# UnitedHealthcare    11142
# Blue Cross          11134
# Medicare            11038
# Aetna               11003
# Name: count, dtype: int64
# --------------------------------------------------
# Admission Type
# Emergency    20104
# Elective     13280
# Urgent       11816
# Routine      10300
# Name: count, dtype: int64
# --------------------------------------------------
# Medication
# Metformin        4653
# Zanamivir        2391
# Methotrexate     2375
# Glipizide        2362
# Orlistat         2351
# Insulin          2340
# Aspirin          2337
# Prednisone       2333
# Oseltamivir      2329
# Tamiflu          2326
# Montelukast      2313
# Memantine        2312
# Azithromycin     2312
# Amoxicillin      2311
# Beta-blockers    2297
# Doxorubicin      2296
# Phentermine      2293
# Donepezil        2292
# Cisplatin        2269
# Statins          2266
# Albuterol        2262
# Rivastigmine     2257
# Ciprofloxacin    2223
# Name: count, dtype: int64
# --------------------------------------------------
# Test Results
# Abnormal        27784
# Normal          17453
# Inconclusive    10263
# Name: count, dtype: int64
# --------------------------------------------------

# %%
print("Distribution of Categorical Variables expressed in Percentage",'\n')
for categorical_columns in Categorical_Target_Columns:
    print(data[categorical_columns].value_counts(normalize=True)*100)
    print("-"*50)
# Out:
# Distribution of Categorical Variables expressed in Percentage
#
# Gender
# Female    50.369369
# Male      49.630631
# Name: proportion, dtype: float64
# --------------------------------------------------
# Blood Type
# O+     28.281081
# A+     28.059459
# B+      9.832432
# AB-     8.081081
# B-      7.942342
# O-      6.019820
# A-      5.947748
# AB+     5.836036
# Name: proportion, dtype: float64
# --------------------------------------------------
# Medical Condition
# Flu              12.695495
# Diabetes         12.621622
# Obesity          12.601802
# Cancer           12.504505
# Asthma           12.446847
# Heart Disease    12.432432
# Alzheimer’s      12.362162
# Infections       12.335135
# Name: proportion, dtype: float64
# --------------------------------------------------
# Doctor
# Michael Smith      0.048649
# John Smith         0.039640
# Robert Smith       0.039640
# Michael Johnson    0.036036
# James Smith        0.036036
#                      ...
# Keith Ortiz        0.001802
# Timothy Chapman    0.001802
# Terri Collins      0.001802
# Jill Jacobson      0.001802
# Scott Coleman      0.001802
# Name: proportion, Length: 40341, dtype: float64
# --------------------------------------------------
# Hospital
# Northwestern Memorial Hospital                 25.351351
# UI Health (University of Illinois Hospital)    25.135135
# UChicago Medicine                              24.990991
# Loyola University Medical Center               24.522523
# Name: proportion, dtype: float64
# --------------------------------------------------
# Insurance Provider
# Cigna               20.149550
# UnitedHealthcare    20.075676
# Blue Cross          20.061261
# Medicare            19.888288
# Aetna               19.825225
# Name: proportion, dtype: float64
# --------------------------------------------------
# Admission Type
# Emergency    36.223423
# Elective     23.927928
# Urgent       21.290090
# Routine      18.558559
# Name: proportion, dtype: float64
# --------------------------------------------------
# Medication
# Metformin        8.383784
# Zanamivir        4.308108
# Methotrexate     4.279279
# Glipizide        4.255856
# Orlistat         4.236036
# Insulin          4.216216
# Aspirin          4.210811
# Prednisone       4.203604
# Oseltamivir      4.196396
# Tamiflu          4.190991
# Montelukast      4.167568
# Memantine        4.165766
# Azithromycin     4.165766
# Amoxicillin      4.163964
# Beta-blockers    4.138739
# Doxorubicin      4.136937
# Phentermine      4.131532
# Donepezil        4.129730
# Cisplatin        4.088288
# Statins          4.082883
# Albuterol        4.075676
# Rivastigmine     4.066667
# Ciprofloxacin    4.005405
# Name: proportion, dtype: float64
# --------------------------------------------------
# Test Results
# Abnormal        50.061261
# Normal          31.446847
# Inconclusive    18.491892
# Name: proportion, dtype: float64
# --------------------------------------------------

# %% [markdown]
# # **Data Cleaning and Pre-Processing**

# %%
#Converting Date Columns to Date Type
data["Date of Admission"] = pd.to_datetime(data["Date of Admission"])
data["Discharge Date"] = pd.to_datetime(data["Discharge Date"])

# %%
print(data[["Date of Admission","Discharge Date"]].dtypes)
# Out:
# Date of Admission    datetime64[ns]
# Discharge Date       datetime64[ns]
# dtype: object

# %%
data[["Date of Admission","Discharge Date"]].sample(2)
# Out:
#       Date of Admission Discharge Date
# 37210        2020-12-13     2020-12-16
# 20120        2022-07-09     2022-08-23

# %%
#Admission and Discharge Date Validation
Date_Validation = data['Discharge Date'] > data['Date of Admission']
print("Are all discharge date valid: ", Date_Validation.all())
print("Total Invalid rows in Date_Validation: ",(~Date_Validation).sum())
# Out:
# Are all discharge date valid:  True
# Total Invalid rows in Date_Validation:  0

# %%
#Length of Stay Validation
Calculated_Length_Of_Stay = (data['Discharge Date'] - data['Date of Admission']).dt.days
Length_Of_Stay_Validation = data['Length of Stay']== Calculated_Length_Of_Stay
print("Does Length of Stay match the Calculated Length_Of_Stay numbers: ", Length_Of_Stay_Validation.all())
print("Total Invalid rows in Length_of_Stay_Validation: ",(~Length_Of_Stay_Validation).sum())
# Out:
# Does Length of Stay match the Calculated Length_Of_Stay numbers:  True
# Total Invalid rows in Length_of_Stay_Validation:  0

# %%
#Billing Amount Validation
Billing_Validation = data['Billing Amount']>0
print("Does Billing Amount is greater than zero: ", Billing_Validation.all())
print("Total Invalid rows in Billing Amount: ",(~Billing_Validation).sum())
# Out:
# Does Billing Amount is greater than zero:  True
# Total Invalid rows in Billing Amount:  0

# %%
#Age Validation
Age_Validation = data['Age'].between(0,100)
print("Are all ages within the valid ranges: ", Age_Validation.all())
print("Total Invalid Values in Ages: ",(~Age_Validation).sum())
# Out:
# Are all ages within the valid ranges:  True
# Total Invalid Values in Ages:  0

# %%
#Cross checking the consistency of Categorical Target Columns
Categorical_Target_Columns = ["Gender","Blood Type", "Medical Condition", "Doctor", "Hospital", "Insurance Provider", "Admission Type", "Medication", "Test Results"]

for categorical_columns in Categorical_Target_Columns:
    print(categorical_columns)
    print(data[categorical_columns].unique())
    print("-"*50)
# Out:
# Gender
# ['Female' 'Male']
# --------------------------------------------------
# Blood Type
# ['AB+' 'B-' 'A+' 'O+' 'O-' 'AB-' 'A-' 'B+']
# --------------------------------------------------
# Medical Condition
# ['Infections' 'Flu' 'Cancer' 'Asthma' 'Heart Disease' 'Alzheimer’s'
#  'Diabetes' 'Obesity']
# --------------------------------------------------
# Doctor
# ['Matthew Smith' 'Samantha Davies' 'Tiffany Mitchell' ... 'Deborah Sutton'
#  'Mary Bartlett' 'Alec May']
# --------------------------------------------------
# Hospital
# ['Northwestern Memorial Hospital'
#  'UI Health (University of Illinois Hospital)' 'UChicago Medicine'
#  'Loyola University Medical Center']
# --------------------------------------------------
# Insurance Provider
# ['Blue Cross' 'UnitedHealthcare' 'Aetna' 'Cigna' 'Medicare']
# --------------------------------------------------
# Admission Type
# ['Emergency' 'Elective' 'Routine' 'Urgent']
# --------------------------------------------------
# Medication
# ['Azithromycin' 'Tamiflu' 'Cisplatin' 'Prednisone' 'Beta-blockers'
#  'Donepezil' 'Zanamivir' 'Aspirin' 'Memantine' 'Metformin' 'Phentermine'
#  'Rivastigmine' 'Albuterol' 'Orlistat' 'Insulin' 'Ciprofloxacin'
#  'Glipizide' 'Oseltamivir' 'Doxorubicin' 'Montelukast' 'Amoxicillin'
#  'Methotrexate' 'Statins']
# --------------------------------------------------
# Test Results
# ['Normal' 'Abnormal' 'Inconclusive']
# --------------------------------------------------

# %% [markdown]
# # **Feature Engineering**

# %%
#Extracting the day, month and year from the Admission Date
data['Day of Admission'] = data['Date of Admission'].dt.day
data['Month of Admission'] = data['Date of Admission'].dt.month
data['Year of Admission'] = data['Date of Admission'].dt.year

# %%
print("Unique values in Admission Year")
print(data["Year of Admission"].unique())
# Out:
# Unique values in Admission Year
# [2024 2019 2022 2020 2023 2021]

# %%
print("Unique values in Admission Day")
print(data["Day of Admission"].unique())
# Out:
# Unique values in Admission Day
# [31 20 22 18 19  3 28  1 23 13 12  8  4 15 21  2 24 17  7 14 27  9  5 29
#  10  6 30 16 11 26 25]

# %%
print("Unique values in Admission Month")
print(data["Month of Admission"].unique())
# Out:
# Unique values in Admission Month
# [ 1  8  9 11 12  7  5  4 10  6  3  2]
